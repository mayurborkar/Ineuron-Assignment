# %% [markdown]
# **1.	Given X be a discrete random variable with the following PMF**
#
# ![image.png](attachment:image.png)
#
#  **a. Find the range RX of the random variable X.**
#
#  **b. Find P(X ≤ 0.5)**
#
#  **c. Find P(0.25<X<0.75)**
#
#  **d. P(X = 0.2|X<0.6)**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question1-1.jpeg'>
#
# <img src = 'Images/Question1-2.jpeg'>

# %% [markdown]
# **2. Two equal and fair dice are rolled, and we observed two numbers X and Y.**
#
#  * Find RX, RY, and the PMFs of X and Y.
#
#  * Find P(X = 2,Y = 6).
#
#  * Find P(X>3|Y = 2).
#
#  * If Z = X + Y. Find the range and PMF of Z.
#
#  * Find P(X = 4|Z = 8).

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question2-1.jpeg'>
#
# <img src = 'Images/Question2-2.jpeg'>
#
# <img src = 'Images/Question2-3.jpeg'>

# %% [markdown]
# **3. In an exam, there were 20 multiple-choice questions. Each question had 44 possible options. A student knew the answer to 10 questions, but the other 10 questions were unknown to him, and he chose answers randomly. If the student X's score is equal to the total number of correct answers, then find out the PMF of X. What is P(X>15)?**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question3.jpeg'>

# %% [markdown]
# **4. The number of students arriving at a college between a time interval is a Poisson random variable. On average, 10 students arrive per hour. Let Y be the number of students arriving from 10 am to 11:30 am. What is P(10<Y≤15)?**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question4.jpeg'>

# %% [markdown]
# **5.Two independent random variables, X and Y,are given such that X~Poisson(α) and Y~Poisson(β). State a new random variable as Z = X + Y. Find out the PMF of Z.**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question5.jpeg'>

# %% [markdown]
# **6. There is a discrete random variable X with the pmf. If we define a new random variable Y = (X + 1)^2 then**
#
# ![image.png](attachment:image.png)
#
# **1. Find the range of Y.**
#
# **2. Find the pmf of Y.**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question6.jpeg'>

# %% [markdown]
# **7. Assuming X is a continuous random variable with PDF**
#
# ![image.png](attachment:image.png)
#
# **1.	Find EX and Var(X).**
#
# **2.	Find P(X ≥  ).**

# %% [markdown]
# <img src = 'Images/Question7-1.jpeg'>
#
# <img src = 'Images/Question7-2.jpeg'>

# %% [markdown]
# **8. If X is a continuous random variable with pdf**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question8.jpeg'>

# %% [markdown]
# **9. If X~Uniform ![image.png](attachment:image.png)  and Y = sin(X), then find fY(y).**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# Here Y=g(X), where g is a differentiable function. Although g is not monotone, it can be divided to a finite number of regions in which it is monotone. Thus, we can use Equation 4.6. We note that since RX=[−π2,π], RY=[−1,1]. By looking at the plot of g(x)=sin(x) over [−π2,π], we notice that for y∈(0,1) there are two solutions to y=g(x), while for y∈(−1,0), there is only one solution. In particular, if y∈(0,1), we have two solutions: x1=arcsin(y), and x2=π−arcsin(y). If y∈(−1,0) we have one solution, x1=arcsin(y). Thus, for y∈(−1,0), we have

# %% [markdown]
# <img src = 'Images/Question9.jpeg'>

# %% [markdown]
# **10. If X is a random variable with CDF**
#
# ![image.png](attachment:image.png)
#
# 1.	What kind of random variable is X: discrete, continuous, or mixed?
# 2.	Find the PDF of X, fX(x).
# 3.	Find E(eX).
# 4.	Find P(X = 0|X≤0.5).

# %% [markdown]
# **Solution:-**

# %% [markdown]
# **11. There are two random variables X and Y with joint PMF given in Table below**
#
# 1.	Find P(X≤2, Y≤4).
# 2.	Find the marginal PMFs of X and Y.
# 3.	Find P(Y = 2|X = 1).
# 4.	Are X and Y independent?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution:-**

# %% [markdown]
# Are X and Y independent? To check whether X and Y are independent, we need to check that P(X=xi,Y=yj)=P(X=xi)P(Y=yj), for all xi∈RX and all yj∈RY. Looking at the table and the results from previous parts, we find

# %% [markdown]
# <img src = 'Images/Question11-1.jpeg'>
#
# <img src = 'Images/Question11-2.jpeg'>

# %% [markdown]
# **12. A box containing 40 white shirts and 60 black shirts. If we choose 10 shirts (without replacement) at random, find the joint PMF of X and Y, where X is the number of white shirts and Y is the number of black shirts.**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question12.jpeg'>

# %% [markdown]
# **13. If A and B are two jointly continuous random variables with joint PDF**
#
# **a. Find fX(a) and fY(b).**
#
# **b. Are A and B independent of each other?**
#
# **c. Find the conditional PDF of A given B = b, fA|B(a|b).**
#
# **d. Find E[A|B = b], for 0 ≤ y ≤ 1.**
#
# **e. Find Var(A|B = b), for 0 ≤ y ≤ 1.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question13-1.jpeg'>
#
# <img src = 'Images/Question13-2.jpeg'>
#
# <img src = 'Images/Question13-3.jpeg'>

# %% [markdown]
# **14. There are 100 men on a ship. If Xi is the ith man's weight on the ship and Xi's are independent and identically distributed and EXi = μ = 170 and σXi = σ = 30. Find the probability that the men's total weight on the ship exceeds 18,000.**

# %% [markdown]
# **Solution:-**

# %% [markdown]
# <img src = 'Images/Question14.jpeg'>

# %% [markdown]
# **15. Let X1, X2, ……, X25 are independent and identically distributed. And have the following PMF. If Y = X1 + X2 + … + Xn, estimate P(4 ≤ Y ≤ 6) using central limit theorem.**

# %% [markdown]
# **Solution:-** Question Is Incomplete
